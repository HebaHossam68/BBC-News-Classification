# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('/content/bbc-text (1).csv')

# %%
data.head()
# Out:
#         category                                               text
# 0           tech  tv future in the hands of viewers with home th...
# 1       business  worldcom boss  left books alone  former worldc...
# 2          sport  tigers wary of farrell  gamble  leicester say ...
# 3          sport  yeading face newcastle in fa cup premiership s...
# 4  entertainment  ocean s twelve raids box office ocean s twelve...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 471 entries, 0 to 470
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   category  471 non-null    object
#  1   text      471 non-null    object
# dtypes: object(2)
# memory usage: 7.5+ KB

# %%
data.isnull().sum()
# Out:
# category    0
# text        0
# dtype: int64

# %%
data.describe()
# Out:
#         category                                               text
# count        471                                                471
# unique         5                                                469
# top     business  hague  given up  his pm ambition former conser...
# freq         122                                                  2

# %%
data['category'].value_counts()
# Out:
# category
# business         122
# sport            109
# politics          92
# entertainment     78
# tech              70
# Name: count, dtype: int64

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
stop_words=set(stopwords.words('english'))
lemmatizer=WordNetLemmatizer()

# %%
def clean_text(text):
  text=text.lower()
  text=re.sub(r'[^a-zA-Z]',' ',text)
  tokens=nltk.word_tokenize(text)
  tokens=[lemmatizer.lemmatize(word) for word in tokens if word not in stop_words]
  cleaned_text=" ".join(tokens)
  return cleaned_text

# %%
data['cleaned_text']=data['text'].apply(clean_text)

# %%
data.head()
# Out:
#         category                                               text  \
# 0           tech  tv future in the hands of viewers with home th...
# 1       business  worldcom boss  left books alone  former worldc...
# 2          sport  tigers wary of farrell  gamble  leicester say ...
# 3          sport  yeading face newcastle in fa cup premiership s...
# 4  entertainment  ocean s twelve raids box office ocean s twelve...
#
#                                         cleaned_text
# 0  tv future hand viewer home theatre system plas...
# 1  worldcom bos left book alone former worldcom b...
# 2  tiger wary farrell gamble leicester say rushed...
# 3  yeading face newcastle fa cup premiership side...
# 4  ocean twelve raid box office ocean twelve crim...

# %%
from sklearn.model_selection import train_test_split
x=data['cleaned_text']
y=data['category']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42,stratify=y)

# %%
print(x_train.shape)
# Out:
# (376,)

# %%
print(y_test.shape)
# Out:
# (95,)

# %%
x_train.head()
# Out:
# 168    blair dismisses quit claim report tony blair d...
# 242    china top trader japan china overtook u become...
# 199    card fraudsters targeting web new safeguard cr...
# 60     telegraph newspaper axe job daily sunday teleg...
# 185    almagro continues spanish surge unseeded nicol...
# Name: cleaned_text, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf=TfidfVectorizer(max_features=5000,ngram_range=(1,2))
x_train_idf=tfidf.fit_transform(x_train)
x_test_idf=tfidf.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,accuracy_score

model=LogisticRegression(max_iter=2000)
model.fit(x_train_idf,y_train)
y_pred=model.predict(x_test_idf)
accuracy=accuracy_score(y_test,y_pred)
print("Accuracy : ",accuracy)
print(classification_report(y_test,y_pred))
# Out:
# Accuracy :  0.9473684210526315
#                precision    recall  f1-score   support
#
#      business       0.89      1.00      0.94        25
# entertainment       0.93      0.88      0.90        16
#      politics       1.00      0.94      0.97        18
#         sport       1.00      1.00      1.00        22
#          tech       0.92      0.86      0.89        14
#
#      accuracy                           0.95        95
#     macro avg       0.95      0.94      0.94        95
#  weighted avg       0.95      0.95      0.95        95

# %%
import keras
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM,Dense,Embedding,Dropout

# %%
tokenizer=Tokenizer(num_words=10000)
tokenizer.fit_on_texts(x_train)

# %%
x_train_seq=tokenizer.texts_to_sequences(x_train)
x_test_seq=tokenizer.texts_to_sequences(x_test)

# %%
print(x_train_seq)
# Out:
, 257, 189, 115, 305, 643, 710, 739, 277, 2, 550, 140, 437, 257, 93, 1475, 1193, 16, 741, 73, 689, 981, 238, 142, 129, 14, 2359, 174, 73, 257, 2687, 19, 239, 711, 873, 239, 4728, 219, 239, 1726, 1475, 1047, 778, 116, 1726, 1047, 778, 3148, 239, 9, 457, 1726, 1475, 2, 230, 1047, 778, 1593, 1594, 114, 508], [135, 3151, 6456, 509, 5, 3779, 458, 6457, 135, 779, 1375, 551, 3151, 1281, 314, 82, 779, 596, 712, 489, 1, 596, 712, 3780, 780, 193, 16, 135, 1113, 712, 77, 597, 326, 82, 1282, 62, 98, 1727, 623, 1728, 135, 4729, 278, 2360, 102, 571, 3152, 1283, 3151, 201, 4730, 780, 193, 1, 1727, 623, 1728, 135, 1376, 185, 458, 135, 712, 644, 1903, 2361, 4731, 1904, 2362, 352, 1728, 28, 1048, 3781, 780, 193, 166, 175, 3782, 4732, 30, 45, 713, 623, 1728, 4, 1729, 135, 712, 135, 1113, 1284, 97, 305, 1476, 1377, 135, 1113, 1284, 3151, 474, 1477, 314, 667, 354, 1378, 354, 3153, 78, 1, 240, 6458, 135, 1113, 712, 21, 62, 98, 2, 712, 3783, 6459, 49, 6460, 781, 1905, 1, 780, 193, 1194, 3784, 623, 1728, 306, 2361, 4733, 2113, 5, 112, 63, 231, 3785, 5, 135, 6461, 43, 355, 151, 782, 1728, 123, 1, 3, 4732, 738, 14, 106, 8, 3154, 1, 137, 623, 1728, 26, 779, 598, 552, 553, 738, 154, 1, 1595, 3786, 1728, 28, 97, 1, 645, 821, 135, 2363, 623, 80, 135, 1730, 4734, 1, 2364, 135, 1906, 1, 21, 2361, 874, 32, 3787, 135, 13, 241, 2, 140, 510, 822, 779, 1731, 53, 3788, 4735, 135, 6462, 21, 1195, 135, 3789, 135, 1113, 712, 624, 400, 213, 303, 920, 115, 413, 314, 712, 3789, 3788, 140, 37], [1276, 487, 4736, 150, 875, 264, 1276, 487, 6463, 1188, 150, 6464, 475, 1276, 36, 16, 185, 490, 414, 382, 5, 2365, 2366, 1188, 22, 1049, 428, 3790, 1478, 3791, 1196, 1285, 185, 74, 2688, 2689, 401, 1732, 2114, 1379, 625, 921, 401, 326, 1379, 232, 327, 1188, 163, 783, 1596, 1597, 2367, 3792, 491, 167, 1114, 1733, 6465, 242, 11, 1, 13, 38, 982, 4737, 2367, 1734, 232, 327, 1188, 1, 2690, 3155, 383, 1188,  ...

# %%
x_train_pad=pad_sequences(x_train_seq,maxlen=200)
x_test_pad=pad_sequences(x_test_seq,maxlen=200)

# %%
print(len(y.unique()))
# Out:
# 5

# %%
from keras.regularizers import l2
model=Sequential()
model.add(Embedding(input_dim=1000,output_dim=32,input_length=200))
model.add(LSTM(units=32,dropout=0.3,recurrent_dropout=0.3))
model.add(Dense(units=16,activation="relu",kernel_regularizer=l2(0.001)))
model.add(Dropout(0.5))
model.add(Dense(units=5,activation="softmax"))

model.build(input_shape=(None, 200))
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_8 (Embedding)         │ (None, 200, 32)        │        32,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_7 (LSTM)                   │ (None, 32)             │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 5)              │            85 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 40,933 (159.89 KB)
#  Trainable params: 40,933 (159.89 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss="sparse_categorical_crossentropy",optimizer="adam",metrics=["accuracy"])

# %%
model.fit(x_train_pad,y_train.factorize()[0],epochs=10,batch_size=16,validation_data=(x_test_pad,y_test.factorize()[0]))
# Out:
# Epoch 1/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 21s 717ms/step - accuracy: 0.2285 - loss: 1.6283 - val_accuracy: 0.2316 - val_loss: 1.6264
# Epoch 2/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 18s 654ms/step - accuracy: 0.2542 - loss: 1.6144 - val_accuracy: 0.2316 - val_loss: 1.6252
# Epoch 3/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 17s 728ms/step - accuracy: 0.2461 - loss: 1.6076 - val_accuracy: 0.2316 - val_loss: 1.6213
# Epoch 4/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 19s 658ms/step - accuracy: 0.3126 - loss: 1.5625 - val_accuracy: 0.2316 - val_loss: 1.6347
# Epoch 5/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - accuracy: 0.3029 - loss: 1.5202 - val_accuracy: 0.2421 - val_loss: 1.7583
# Epoch 6/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 56s 2s/step - accuracy: 0.4526 - loss: 1.3740 - val_accuracy: 0.2632 - val_loss: 1.7475
# Epoch 7/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 52s 650ms/step - accuracy: 0.4359 - loss: 1.3329 - val_accuracy: 0.2421 - val_loss: 1.9944
# Epoch 8/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - accuracy: 0.5255 - loss: 1.2208 - val_accuracy: 0.2000 - val_loss: 2.0967
# Epoch 9/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.4354 - loss: 1.2123 - val_accuracy: 0.1368 - val_loss: 2.0869
# Epoch 10/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 16s 653ms/step - accuracy: 0.4997 - loss: 1.1464 - val_accuracy: 0.2211 - val_loss: 2.4030

# %%
from transformers import BertTokenizer, TFBertForSequenceClassification
from transformers import create_optimizer
from tensorflow.keras.losses import SparseCategoricalCrossentropy

tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

def encode_texts(texts, tokenizer, max_len=128):
    return tokenizer(texts.tolist(), padding=True, truncation=True, return_tensors="tf", max_length=max_len)

train_encodings = encode_texts(x_train, tokenizer)
test_encodings = encode_texts(x_test, tokenizer)

model_bert = TFBertForSequenceClassification.from_pretrained("bert-base-uncased", num_labels=len(y.unique()), from_pt=True)
batch_size = 16
epochs = 3
num_train_steps = (len(x_train) // batch_size) * epochs
optimizer, lr_schedule = create_optimizer(
    init_lr=2e-5,
    num_warmup_steps=0,
    num_train_steps=num_train_steps
)
model_bert.compile(optimizer=optimizer, loss=SparseCategoricalCrossentropy(from_logits=True), metrics=["accuracy"])

history = model_bert.fit(
    x=dict(train_encodings),
    y=y_train.factorize()[0],
    validation_data=(dict(test_encodings), y_test.factorize()[0]),
    epochs=3,
    batch_size=16
)
# Out:
# All PyTorch model weights were used when initializing TFBertForSequenceClassification.
#
# Some weights or buffers of the TF 2.0 model TFBertForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/3
# 24/24 [==============================] - 66s 637ms/step - loss: 1.3545 - accuracy: 0.5665 - val_loss: 1.6196 - val_accuracy: 0.1895
# Epoch 2/3
# 24/24 [==============================] - 12s 500ms/step - loss: 0.7649 - accuracy: 0.9335 - val_loss: 1.8752 - val_accuracy: 0.2632
# Epoch 3/3
# 24/24 [==============================] - 12s 488ms/step - loss: 0.5233 - accuracy: 0.9734 - val_loss: 1.9868 - val_accuracy: 0.2737
